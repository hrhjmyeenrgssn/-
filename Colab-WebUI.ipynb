# %% [markdown]
# <a href="https://colab.research.google.com/github/hrhjmyeenrgssn/-/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py

# %%
# !/usr/local/envs/GPTSoVITS/bin/python -m pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu118

# !/usr/local/envs/GPTSoVITS/bin/python -m pip install traitlets==5.9.0 ipython==8.10.0

# !sudo add-apt-repository -y ppa:ubuntu-toolchain-r/test
# !sudo apt-get update
# !sudo apt-get install -y libstdc++6
# !rm -f /usr/local/lib/libstdc++.so.6
# !ln -s /usr/lib/x86_64-linux-gnu/libstdc++.so.6 /usr/local/lib/libstdc++.so.6
# !rm -f /usr/local/envs/GPTSoVITS/lib/libstdc++.so.6*
# !cp /usr/lib/x86_64-linux-gnu/libstdc++.so.6 /usr/local/envs/GPTSoVITS/lib/
